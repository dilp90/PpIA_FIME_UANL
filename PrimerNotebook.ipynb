# %% [markdown]
# <a href="https://colab.research.google.com/github/dilp90/PpIA_FIME_UANL/blob/main/PrimerNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Este es mi primer notebook**

# %%
print("¡hola mundo!")
# Out:
# ¡hola mundo!
